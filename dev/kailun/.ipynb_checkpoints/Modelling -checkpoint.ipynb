# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import sklearn.model_selection as ms
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
#pip install -U imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Using cached https://files.pythonhosted.org/packages/c8/73/36a13185c2acff44d601dc6107b5347e075561a49e15ddd4e69988414c3e/imbalanced_learn-0.6.2-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: numpy>=1.11 in c:\users\17812\appdata\local\continuum\anaconda3\lib\site-packages (from imbalanced-learn) (1.16.5)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\17812\appdata\local\continuum\anaconda3\lib\site-packages (from imbalanced-learn) (0.13.2)
# Requirement already satisfied, skipping upgrade: scipy>=0.17 in c:\users\17812\appdata\local\continuum\anaconda3\lib\site-packages (from imbalanced-learn) (1.3.1)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.22 in c:\users\17812\appdata\local\continuum\anaconda3\lib\site-packages (from imbalanced-learn) (0.22.2.post1)
# Installing collected packages: imbalanced-learn
# Successfully installed imbalanced-learn-0.6.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import roc_auc_score, roc_curve, auc, average_precision_score
from sklearn.metrics import confusion_matrix

# %%
names = ["Nearest Neighbors", "Gaussian Process",
          "Neural Net", "AdaBoost","Naive Bayes", "QDA"]

# %%
classifiers = [
    KNeighborsClassifier(3),
    GaussianProcessClassifier(1.0 * RBF(1.0)),
    MLPClassifier(alpha=0.3, max_iter=1000),
    AdaBoostClassifier(),
    GaussianNB(),
    QuadraticDiscriminantAnalysis()]

# %% [markdown]
# ### Read in CSV

# %%
filename=r'all_features.csv'
data=pd.read_csv(filename)
data.shape[0]
# Out:
# 68508

# %%
data.columns
# Out:
# Index(['encounter_id', 'HbA1c_High_CH', 'HbA1c_High_NoCH', 'HbA1c_Norm',
#        'diag1_collapse_circulatory', 'diag1_collapse_digestive',
#        'diag1_collapse_genit', 'diag1_collapse_injury',
#        'diag1_collapse_muscul', 'diag1_collapse_neoplasms',
#        'diag1_collapse_other', 'diag1_collapse_respiratory', 'age_bin_60+',
#        'age_bin_<30', 'medical_specialty_short_ER_trauma',
#        'medical_specialty_short_gp', 'medical_specialty_short_inter_med',
#        'medical_specialty_short_missing', 'medical_specialty_short_other',
#        'medical_specialty_short_surgery', 'race_Asian', 'race_Caucasian',
#        'race_Hispanic', 'race_Other', 'discharge_other',
#        'admission_source_collapse_other', 'admission_source_collapse_referral',
#        'admission_source_collapse_transfer', 'time_in_hospital',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_diagnoses', 'number_outpatient_log1p', 'number_emergency_log1p',
#        'number_inpatient_log1p', 'readmitted_yes'],
#       dtype='object')

# %% [markdown]
# ### Create hold out 10% data as validation set along wth test_train split

# %%
validation_index=list(data.sample(int(np.ceil(0.1*data.shape[0]))).index)
validation_data=data.loc[validation_index]
new_Idx = list(set(data.index) - set(validation_index))
data_X_y=data.loc[new_Idx]

# %%
# create a csv to load into other models 
validation_data.to_csv('validation.csv', index=True)

# %%
data_X_y.shape[0]+validation_data.shape[0] # should equal to 68508
# Out:
# 68508

# %%
X_val= validation_data.iloc[:,1:validation_data.shape[1]-1]
y_val= validation_data['readmitted_yes']  
X_val_stand = StandardScaler().fit_transform(X_val)  # preprocess dataset by standarizing X data

# %%
X= data_X_y.iloc[:,0:data_X_y.shape[1]-1]
y= data_X_y['readmitted_yes'] # do not make y a dataframe, x and y should both be np arrays
X_stand = StandardScaler().fit_transform(X.iloc[:,1:X.shape[1]])  # preprocess dataset by standarizing X data 
X_id= X['encounter_id'].to_numpy(dtype=float).reshape(61657,1)
X_stand_all= np.append(X_id, X_stand, axis=1)

# %%
X_stand_all_df = pd.DataFrame(X_stand_all, columns = list(X.columns))

# %%
X_stand_all_df
# Out:
#        encounter_id  HbA1c_High_CH  HbA1c_High_NoCH  HbA1c_Norm  \
# 0         2278392.0      -0.246248        -0.176513   -0.323431
# 1          149190.0      -0.246248        -0.176513   -0.323431
# 2           64410.0      -0.246248        -0.176513   -0.323431
# 3          500364.0      -0.246248        -0.176513   -0.323431
# 4           16680.0      -0.246248        -0.176513   -0.323431
# ...             ...            ...              ...         ...
# 61652   443842016.0      -0.246248        -0.176513    3.091846
# 61653   443842022.0       4.060954        -0.176513   -0.323431
# 61654   443842070.0      -0.246248        -0.176513   -0.323431
# 61655   443842340.0      -0.246248        -0.176513   -0.323431
# 61656   443867222.0      -0.246248        -0.176513   -0.323431
#
#        diag1_collapse_circulatory  diag1_collapse_digestive  \
# 0                       -0.031469                 -0.319655
# 1                       -0.031469                 -0.319655
# 2                       -0.031469                 -0.319655
# 3                       -0.031469                 -0.319655
# 4                       -0.031469                 -0.319655
# ...                           ...                       ...
# 61652                   -0.031469                  3.128376
# 61653                   -0.031469                 -0.319655
# 61654                   -0.031469                 -0.319655
# 61655                   -0.031469                 -0.319655
# 61656                   -0.031469                  3.128376
#
#        diag1_collapse_genit  diag1_collapse_injury  diag1_collapse_muscul  \
# 0                 -0.228598              -0.268393              -0.246766
# 1                 -0.228598              -0.268393              -0.246766
# 2                 -0.228598              -0.268393              -0.246766
# 3                 -0.228598              -0.268393              -0.246766
# 4                 -0.228598              -0.268393              -0.246766
# ...                     ...                    ...                    ...
# 61652             -0.228598              -0.268393              -0.246766
# 61653              4.374493              -0.268393              -0.246766
# 61654             -0.228598               3.725884              -0.246766
# 61655             -0.228598              -0.268393              -0.246766
# 61656             -0.228598              -0.268393              -0.246766
#
#        diag1_collapse_neoplasms  ...  admission_source_collapse_referral  \
# 0                     -0.198485  ...                            1.442995
# 1                     -0.198485  ...                           -0.693003
# 2                     -0.198485  ...                           -0.693003
# 3                     -0.198485  ...                           -0.693003
# 4                      5.038151  ...                           -0.693003
# ...                         ...  ...                                 ...
# 61652                 -0.198485  ...                           -0.693003
# 61653                 -0.198485  ...                           -0.693003
# 61654                 -0.198485  ...                           -0.693003
# 61655                 -0.198485  ...                           -0.693003
# 61656                 -0.198485  ...                           -0.693003
#
#        admission_source_collapse_transfer  time_in_hospital  \
# 0                               -0.262653         -1.116644
# 1                               -0.262653         -0.436933
# 2                               -0.262653         -0.776789
# 3                               -0.262653         -0.776789
# 4                               -0.262653         -1.116644
# ...                                   ...               ...
# 61652                           -0.262653          1.602199
# 61653                           -0.262653          3.301475
# 61654                           -0.262653         -0.776789
# 61655                           -0.262653          0.242777
# 61656                           -0.262653          0.582633
#
#        num_lab_procedures  num_procedures  num_medications  number_diagnoses  \
# 0               -0.094637       -0.812308        -1.771860         -3.134748
# 1                0.808526       -0.812308         0.281623          0.879107
# 2               -1.599909        2.045872        -0.322343         -0.626089
# 3                0.055890       -0.240672         0.040036         -0.124357
# 4                0.407120       -0.812308        -0.926308         -1.127821
# ...                   ...             ...              ...               ...
# 61652            0.356945        0.330964         2.093519          0.879107
# 61653            1.510987        2.617507         1.247968          0.879107
# 61654            0.156242        2.617507         0.160830          0.879107
# 61655            1.661514       -0.240672         0.764795          0.879107
# 61656           -1.499558        0.902600        -1.530274          0.879107
#
#        number_outpatient_log1p  number_emergency_log1p  number_inpatient_log1p
# 0                    -0.354536               -0.267254               -0.343921
# 1                    -0.354536               -0.267254               -0.343921
# 2                     2.521992               -0.267254                1.982593
# 3                    -0.354536               -0.267254               -0.343921
# 4                    -0.354536               -0.267254               -0.343921
# ...                        ...                     ...                     ...
# 61652                -0.354536               -0.267254               -0.343921
# 61653                -0.354536                2.730104               -0.343921
# 61654                 1.460351                2.730104                1.982593
# 61655                -0.354536                2.730104               -0.343921
# 61656                -0.354536               -0.267254               -0.343921
#
# [61657 rows x 36 columns]

# %%
print(len(index.unique()))
print(len(X_stand))
# Out:
# 61657
# 61657

# %%
print(X_stand.shape)
print(X_id.shape)
# Out:
# (61657, 35)
# (61657, 1)

# %% [markdown]
# ### Implement SMOTE: upsampling for imbalanced dataset for train test and validation

# %%
print('Original dataset shape {}'.format(Counter(y)))
sm = SMOTE(random_state=20)
train_input_new, train_output_new = sm.fit_sample(X_stand_all, y) 
print('New dataset shape {}'.format(Counter(train_output_new)))
# Out:
# Original dataset shape Counter({0: 56143, 1: 5514})
# New dataset shape Counter({0: 56143, 1: 56143})

# %%
train_input_new_df = pd.DataFrame(train_input_new, columns = list(X.columns))
train_input_new_df
# Out:
#         encounter_id  HbA1c_High_CH  HbA1c_High_NoCH  HbA1c_Norm  \
# 0       2.278392e+06      -0.246248        -0.176513   -0.323431
# 1       1.491900e+05      -0.246248        -0.176513   -0.323431
# 2       6.441000e+04      -0.246248        -0.176513   -0.323431
# 3       5.003640e+05      -0.246248        -0.176513   -0.323431
# 4       1.668000e+04      -0.246248        -0.176513   -0.323431
# ...              ...            ...              ...         ...
# 112281  1.206920e+08      -0.246248        -0.176513   -0.323431
# 112282  6.248012e+07      -0.246248        -0.176513    1.928634
# 112283  3.894505e+07       1.046769        -0.176513   -0.323431
# 112284  4.713210e+07      -0.246248        -0.176513   -0.323431
# 112285  1.353821e+08      -0.246248        -0.176513   -0.323431
#
#         diag1_collapse_circulatory  diag1_collapse_digestive  \
# 0                        -0.031469                 -0.319655
# 1                        -0.031469                 -0.319655
# 2                        -0.031469                 -0.319655
# 3                        -0.031469                 -0.319655
# 4                        -0.031469                 -0.319655
# ...                            ...                       ...
# 112281                   -0.031469                  3.119390
# 112282                   -0.031469                 -0.319655
# 112283                   -0.031469                 -0.319655
# 112284                   -0.031469                 -0.319655
# 112285                   -0.031469                 -0.319655
#
#         diag1_collapse_genit  diag1_collapse_injury  diag1_collapse_muscul  \
# 0                  -0.228598              -0.268393              -0.246766
# 1                  -0.228598              -0.268393              -0.246766
# 2                  -0.228598              -0.268393              -0.246766
# 3                  -0.228598              -0.268393              -0.246766
# 4                  -0.228598              -0.268393              -0.246766
# ...                      ...                    ...                    ...
# 112281             -0.228598              -0.257983              -0.246766
# 112282              2.806722              -0.268393              -0.246766
# 112283             -0.228598              -0.268393              -0.246766
# 112284             -0.228598              -0.268393              -0.246766
# 112285             -0.228598               1.171249              -0.246766
#
#         diag1_collapse_neoplasms  ...  admission_source_collapse_referral  \
# 0                      -0.198485  ...                            1.442995
# 1                      -0.198485  ...                           -0.693003
# 2                      -0.198485  ...                           -0.693003
# 3                      -0.198485  ...                           -0.693003
# 4                       5.038151  ...                           -0.693003
# ...                          ...  ...                                 ...
# 112281                 -0.198485  ...                           -0.693003
# 112282                 -0.198485  ...                            0.034498
# 112283                 -0.198485  ...                           -0.693003
# 112284                 -0.198485  ...                           -0.693003
# 112285                 -0.198485  ...                            0.673125
#
#         admission_source_collapse_transfer  time_in_hospital  \
# 0                                -0.262653         -1.116644
# 1                                -0.262653         -0.436933
# 2                                -0.262653         -0.776789
# 3                                -0.262653         -0.776789
# 4                                -0.262653         -1.116644
# ...                                    ...               ...
# 112281                           -0.262653         -0.438705
# 112282                           -0.262653          1.486447
# 112283                           -0.262653          1.669765
# 112284                           -0.262653          2.220087
# 112285                           -0.262653          0.962112
#
#         num_lab_procedures  num_procedures  num_medications  number_diagnoses  \
# 0                -0.094637       -0.812308        -1.771860         -3.134748
# 1                 0.808526       -0.812308         0.281623          0.879107
# 2                -1.599909        2.045872        -0.322343         -0.626089
# 3                 0.055890       -0.240672         0.040036         -0.124357
# 4                 0.407120       -0.812308        -0.926308         -1.127821
# ...                    ...             ...              ...               ...
# 112281            0.405159        1.468277        -0.925049         -0.125664
# 112282            0.928855        1.461790         0.191451          0.195566
# 112283            0.652912       -0.297495         0.994134         -0.927327
# 112284            1.146156        0.330964         0.951468          0.742286
# 112285            0.364566        0.696567         5.322906         -1.168601
#
#         number_outpatient_log1p  number_emergency_log1p  \
# 0                     -0.354536               -0.267254
# 1                     -0.354536               -0.267254
# 2                      2.521992               -0.267254
# 3                     -0.354536               -0.267254
# 4                     -0.354536               -0.267254
# ...                         ...                     ...
# 112281                -0.354536               -0.267254
# 112282                -0.354536               -0.267254
# 112283                -0.354536               -0.267254
# 112284                -0.354536                1.912732
# 112285                -0.354536                0.813072
#
#         number_inpatient_log1p
# 0                    -0.343921
# 1                    -0.343921
# 2                     1.982593
# 3                    -0.343921
# 4                    -0.343921
# ...                        ...
# 112281               -0.343921
# 112282                0.448468
# 112283               -0.343921
# 112284                1.348159
# 112285               -0.343921
#
# [112286 rows x 36 columns]

# %%
train_input_new_df['encounter_id'].astype(int)
# Out:
# 0           2278392
# 1            149190
# 2             64410
# 3            500364
# 4             16680
#             ...
# 112281    120691999
# 112282     62480117
# 112283     38945046
# 112284     47132097
# 112285    135382108
# Name: encounter_id, Length: 112286, dtype: int32

# %%
# run this cell if we want everything as training data 
X_train=train_input_new
y_train=train_output_new

# %%
# save SMOTE data to csv
after_upsampling_X = pd.DataFrame(X_train, columns = list(X.columns))
after_upsampling_y = pd.DataFrame(y_train, columns = ['readmitted_yes'])
after_upsampling_X.to_csv('X_train_all.csv', index=True)
after_upsampling_y.to_csv('y_train_all.csv', index=True)

# %%
after_upsampling_X.shape
# Out:
# (112286, 35)

# %%
print('Original dataset shape {}'.format(Counter(y_val)))
#sm = SMOTE(random_state=20)
#X_val_stand, y_val = sm.fit_sample(X_val_stand, y_val)
#print('New dataset shape {}'.format(Counter(y_val)))
# Out:
# Original dataset shape Counter({0: 6242, 1: 609})

# %%
#train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
#X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.3, random_state=0)

# %%
#X_val_train, X_val_test, y_val_train, y_val_test = train_test_split(train_val_input_new, train_val_output_new, test_size=0.20, random_state=0)

# %% [markdown]
# ### Tree Models:
#
# Fit with decision model with max_depth = 28, criterion= entropy, min
#
# Fit with 10 fold cross validation grid search

# %% [markdown]
# #### Decision tree without cross validation:

# %%
dtree = DecisionTreeClassifier(max_depth=28, criterion = "entropy", min_samples_split=10)
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=28, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
dtree_pred = dtree.predict(X_val_stand)  # predict on data the model has never seen before 
confusion_matrix(y_val, dtree_pred)
# Out:
# array([[  83, 6123],
#        [  13, 6193]], dtype=int64)

# %%
#dtree_probs=dtree.predict_proba(X_test)[:,1]
dtree_probs_val= dtree.predict_proba(X_val_stand)[:,1]

# %%
# Calculate roc auc
#roc_value = roc_auc_score(y_test, dtree_probs)
roc_value_val= roc_auc_score(y_val, dtree_probs_val)

# %%
roc_value_val
# Out:
# 0.5060410335490827

# %%
print("Accuracy is {0:.2f}".format(accuracy_score(y_val, dtree_pred)))
print("Precision is {0:.2f}".format(precision_score(y_val, dtree_pred)))
print("Recall is {0:.2f}".format(recall_score(y_val, dtree_pred)))
# Out:
# Accuracy is 0.10
# Precision is 0.09
# Recall is 0.98

# %% [markdown]
# #### Decision Tree with grid search cross_validation

# %%
grid_para_tree =  {'max_depth': range(1, 31),
    'criterion': ['gini', 'entropy']}


dtree.set_params(random_state=0)
grid_search_tree = ms.GridSearchCV(dtree, grid_para_tree, scoring='accuracy', cv=10, n_jobs=-1, return_train_score=True)
grid_search_tree.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='entropy', max_depth=28,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=10,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
#                                               random_state=0, splitter='best'),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 31)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='accuracy', verbose=0)

# %%
print('The best score is %.4f' %grid_search_tree.best_score_)
print('The training score is %.4f' %(grid_search_tree.best_estimator_.score(X_train, y_train)))
print('The validation score is %.4f' %(grid_search_tree.best_estimator_.score(X_val_stand, y_val)))
# Out:
# The best score is 0.8996
# The training score is 0.9618
# The validation score is 0.5037

# %%
rm = RandomForestClassifier(n_estimators = 10, max_depth=25, criterion = "gini", min_samples_split=10)
rm.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=25, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rm_prd = rm.predict(X_test)
confusion_matrix(y_test, rm_prd)
# Out:
# array([[16102,   748],
#        [ 1993, 14849]], dtype=int64)

# %%
np.unique(rm_prd, return_counts=True)
tn,fp,fn,tp=confusion_matrix(y_test, rm_prd).ravel()
print(tn, fp, fn, tp)
# Out:
# 16102 748 1993 14849

# %%
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, rm_prd)))
print("Precision is {0:.2f}".format(precision_score(y_test, rm_prd)))
print("Recall is {0:.2f}".format(recall_score(y_test, rm_prd)))
# Out:
# Accuracy is 0.92
# Precision is 0.95
# Recall is 0.88

# %%
rm_prd_validation = rm.predict(X_val_stand)
print("Validation Accuracy is {0:.2f}".format(accuracy_score(y_val, rm_prd_validation)))
# Out:
# Validation Accuracy is 0.52

# %%
# Create list of top most features based on importance
feature_names = X.columns
feature_imports = rm.feature_importances_
most_imp_features = pd.DataFrame([f for f in zip(feature_names,feature_imports)], columns=["Feature", "Importance"]).nlargest(20, "Importance")
most_imp_features.sort_values(by="Importance", inplace=True)
plt.figure(figsize=(10,6))
plt.barh(range(len(most_imp_features)), most_imp_features.Importance, align='center', alpha=0.8)
plt.yticks(range(len(most_imp_features)), most_imp_features.Feature, fontsize=14)
plt.xlabel('Importance')
plt.title('Most important features - Random Forest ')
plt.show()

# %% [markdown]
# ### Multilayer Perceptron
#
# Here's a nonlinear model with just one hidden layer

# %%
clf=MLPClassifier(activation='relu', alpha=0.0001, hidden_layer_sizes= (1500,), max_iter=1000, warm_start=False)

# %%
# SMOTE Data
clf2=MLPClassifier(activation='relu', alpha=0.0001, hidden_layer_sizes= (1500,), max_iter=1000, warm_start=False)

# %%
# Non SMOTE Data
clf3=MLPClassifier(activation='relu', alpha=0.0001, hidden_layer_sizes= (1500,), max_iter=1000, warm_start=False)

# %%
clf3.fit(X_stand, y)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(1500,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=1000,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
multi_layer_perceptron_probs_val= clf2.predict_proba(X_val_stand)[:,1]
auc_prob= roc_auc_score(y_val, multi_layer_perceptron_probs_val)
avg_precision= average_precision_score(y_val, multi_layer_perceptron_probs_val)

# %%
auc_prob
# Out:
# 0.5216083020891837

# %%
avg_precision
# Out:
# 0.10116005861146043

# %%
multi_layer_perceptron_probs_val[0:50]
# Out:
# array([1.26130866e-02, 3.09226419e-06, 2.49972413e-04, 6.32356267e-02,
#        1.17771034e-01, 9.71612792e-01, 6.94225632e-04, 1.16503703e-03,
#        3.88815080e-02, 1.09567600e-05, 3.13228687e-01, 3.42176519e-03,
#        8.75321495e-08, 9.29925629e-03, 6.46815083e-06, 4.54594518e-01,
#        9.27526800e-01, 5.37631079e-01, 3.46062509e-03, 7.84144399e-03,
#        5.86314444e-01, 1.86412528e-01, 4.83078070e-02, 1.82930905e-01,
#        1.38251205e-03, 4.58846716e-04, 5.35404361e-02, 4.81947125e-01,
#        5.11422116e-01, 1.89574541e-01, 2.11446266e-03, 6.10056289e-02,
#        2.81537098e-02, 5.78275541e-01, 1.79869691e-02, 4.13363548e-04,
#        2.76651081e-10, 9.97912126e-01, 1.77129742e-02, 1.22589475e-02,
#        6.63328954e-01, 5.23782712e-02, 3.01964380e-06, 3.05849284e-08,
#        1.91307654e-01, 3.35124163e-03, 4.71461631e-05, 1.01355359e-03,
#        7.27414221e-01, 4.16863610e-01])

# %%
clf3.score(X_val_stand, y_val)
# Out:
# 0.8671726755218216

# %%
multi_perceptron_pred = clf3.predict(X_val_stand)
confusion_matrix(y_val, multi_perceptron_pred)
# Out:
# array([[5896,  319],
#        [ 591,   45]], dtype=int64)

# %%
tn, fp, fn, tp = confusion_matrix(y_val, multi_perceptron_pred).ravel()
(tn, fp, fn, tp)
# Out:
# (5896, 319, 591, 45)

# %%
specificity= tn/(tn+fp)
specificity
# Out:
# 0.9486725663716814

# %%
sensitivity= tp/(tp+fn)
sensitivity
# Out:
# 0.07075471698113207

# %%
precision=tp/(tp+fp)
precision
# Out:
# 0.12362637362637363

# %%
fpr, tpr, thresholds = roc_curve(y_val, multi_perceptron_pred, pos_label=1)
auc(fpr, tpr)
# Out:
# 0.5097136416764068

# %%
fpr
# Out:
# array([0.        , 0.12085079, 1.        ])

# %%
import pickle
# save the model to disk
filename = 'finalized_model2.sav'
pickle.dump(clf2, open(filename, 'wb'))

# %%
# load the model from disk
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, Y_test)
print(result)
